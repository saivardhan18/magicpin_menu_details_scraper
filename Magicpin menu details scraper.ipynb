# %%
import requests
from bs4 import BeautifulSoup

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"}

url = "https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/delivery/"

response = requests.get(url, headers=headers)


soup = BeautifulSoup(response.content, "html.parser")
catalog_items_holder = soup.find("div", class_="catalogItemsHolder")

if catalog_items_holder:
  
    menu_items = catalog_items_holder.find_all("article", class_="categoryListing")

    for item in menu_items:
        # Extract heading
        heading = item.find("h4", class_="categoryHeading").text.strip()

        # Extract item name and price within the category
        item_details = item.find_all("div", class_="itemDetails")

        for item_detail in item_details:
            # Extract item name
            item_name = item_detail.find("a", class_="itemName").text.strip()

            # Extract item price
            item_price = item_detail.find("span", class_="itemPrice").text.strip()
            
            item_price_numeric = pd.to_numeric(item_price.replace("₹", "").replace(",", ""))

            print(f"{heading}, {item_name}, {item_price}")
# Out:
# Kulcha Burger, Peri-Peri Paneer Kulcha Burger, ₹308
# Kulcha Burger, Peri-Peri Chicken Kulcha Burger, ₹319
# Kulcha Burger, Butter Chicken Kulcha Burger, ₹259
# Kulcha Burger, Chicken Keema Kulcha Burger, ₹259
# Chinese Fried Rice & Noodle Bowl, Veg Manchurian Gravy, ₹198
# Chinese Fried Rice & Noodle Bowl, Chilli Garlic Paneer, ₹260
# Chinese Fried Rice & Noodle Bowl, Chicken Manchurian Gravy, ₹281
# Chinese Fried Rice & Noodle Bowl, Veg Manchurian Fried Rice Bowl, ₹268
# Chinese Fried Rice & Noodle Bowl, Chicken Manchurian Fried Rice Bowl, ₹299
# Chinese Fried Rice & Noodle Bowl, Chilli Garlic Paneer Fried Rice Bowl, ₹288
# Chinese Fried Rice & Noodle Bowl, Chilli Garlic Chicken Fried Rice Bowl, ₹308
# 3 Layer Rice Bowl, Kadhai Paneer, Soya Masala Sabzi & Jeera Pulao, ₹259
# 3 Layer Rice Bowl, Yellow Dal Tadka, Bhindi Chana & Jeera Pulao, ₹229
# 3 Layer Rice Bowl, Ghar Ke Rajma, Aloo Gobhi & Jeera Pulao, ₹239
# 3 Layer Rice Bowl, Butter Paneer, Aloo Gobhi & Jeera Pulao, ₹268
# ...

# %%
df = pd.DataFrame(data)

df.to_excel("Magicpin_menu_data.xlsx", index=False)

print("Data has been successfully extracted to 'Magicpin_menu_data.xlsx'")
# Out:
# Data has been successfully exported to 'Magicpin_menu_data.xlsx'
